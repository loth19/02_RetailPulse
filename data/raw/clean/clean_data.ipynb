# %% [markdown]
# # Nettoyage des donneesNotebook restaure: version JSON valide pour GitHub.

# %%
import pandas as pddf_clients = pd.read_csv('../clients.csv')df_produits = pd.read_csv('../produits.csv')df_commandes = pd.read_csv('../commandes.csv')

# %%
df_clients['email'] = df_clients['email'].fillna('inconnue')df_commandes = df_commandes.drop_duplicates()df_commandes = df_commandes[df_commandes['montant_total'] > 0]

# %%
import osos.makedirs('data/clean', exist_ok=True)df_clients.to_csv('data/clean/clients.csv', index=False)df_commandes.to_csv('data/clean/commandes.csv', index=False)df_produits.to_csv('data/clean/produits.csv', index=False)
